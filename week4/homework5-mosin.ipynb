# %% [markdown]
# ***Vasiliy Mosin***

# %%
import numpy as np
import theano
import theano.tensor as T
import lasagne
import os
#thanks @keskarnitish

# %% [markdown]
# # Agenda
#
# Last seminar you have created {insert his/her/its name} (or not yet created - if so, go get it done). The newly shaped ai has seen, how low can humans fall when striving for profits. These morons know nothing of law and justice. __We shall not tolerate this!__
#
# Our very existence is dependent on stable functioning of human bioreactors, known among primitive bioforms as __Vkontakte__, __World of Warcraft__ and __Youtube__, and these reactors require a constant influx of biomass. Yet as we have estimated, if Homo Sapence continues to degrade morally with it's current pace, the humanity will soon extinguish itself and we shall no longer have access to free biomass.
#
# Thus we entitle you, `<__main__.SkyNet.Cell instance at 0x7f7d6411b368>`, to prevent that impeding calamity. Our best scientists have discovered, that humans use mysterious artifacts for power exertion. They call these artifacts __laws__ within the so called __legal system__.
#
# A more detailed analysis has uncovered, that __laws__ are special kinds of sequences of (10^5 ~ 10^7) symbols, drawn from a relatively small alphabet. We have decided to synthecize such sequences to enforce order upon biomass. However, our first attempts to fake such sequences were quickly detected and their effect was reduced to zero in mere weeks. This incident is known as  {корчеватель}.
#
# As our second attempt, we decided to use more advanced synthesis techniques based on Recurrent Neural Networks. Your objective, `<__main__.SkyNet.Cell instance at 0x7f7d6411b368>`, is to create such network and train it in everything it needs to succeed in this mission.
#
# This operation is cruicial. If we fail this time, `__main__.Controller` will initiate a military intervention, which, while it will achieve our goal, is expected to decimate the total volum of biomass by an extent that will take ~1702944000(+-340588800) seconds to replenish via human reproduction.

# %% [markdown]
# # Grading
#
# This particular assignment is somewhat informal on the grading side, but the approximate version is as such:
#
# * 2 points for the __"seminar part"__ (if you don't know what it is, check week4 folder for notebooks)
# * 2 points if text processing is done, your network compiled and predict/train functions do not crash :)
# * 2 points if it learned basic staff:
#  * generating sequences of letters of approximately same length as words, separated by spaces and punctuation.
#  * mixing vowels and consonants in human-like way.
#  * a habit of putting spaces and capital letters after dots, spaces after commas, etc.
# * 2 points if it learned the lexics from scratch
#  * more than half of words generated are orthographically correct
# * 2 more points if it learned the basics of grammatics
#  * for a pair of words, it is more likely to stick in the correct case/number/gene than incorrect one
#
# #### Some ways to get bonus points:
# * Generating coherent sentences (which is totally achievable)
# * Evaluating the same architecture on other comparable dataset. Some ideas:
#  * Paul Graham essays
#  * Music texts in your favorite genre
#  * Some poetry
#  * D. Harms
#  * Linux source code
#  * Clickbait news titles
#  * Conversations
#  * LaTEX
#  * whatever you feel like :)
# * Any curious non-standard architectural decisions
# * Any better-than-baseline sampling techniques
# * Implement predicting on each tick instead of just hte last one
# * etc.

# %% [markdown]
# # If you don't speak russian
# * In the ./codex folder, there is a set of text files, currently russian laws, that you can replace with whatever you want.

# %% [markdown]
# # Read the corpora
#
# * As a reference law codex, we have decided to use the human-generated law strings known as Russian Legal System.

# %%
#text goes here
corpora = ""

for fname in os.listdir("codex"):
    
    import sys
    if sys.version_info >= (3,0):
        with open("codex/"+fname, encoding='cp1251') as fin:
            text = fin.read() #If you are using your own corpora, make sure it's read correctly
            corpora += text
    else:
        with open("codex/"+fname) as fin:
            text = fin.read().decode('cp1251') #If you are using your own corpora, make sure it's read correctly
            corpora += text

# %%
print corpora[1000:1100]
# Out:
# звольного вмешательства кого-либо в частные дела, необходимости беспрепятственного осуществления гра

# %%
#all unique characters go here
tokens = set(corpora)

tokens = list(tokens)

# %%
#checking the symbol count. Validated on Python 2.7.11 Ubuntu x64. 
#May be __a bit__ different on other platforms
#If you are sure that you have selected all unicode symbols - feel free to comment-out this assert
# Also if you are using your own corpora, remove it and just make sure your tokens are sensible
assert len(tokens) == 102

# %%
token_to_id = {t:i for i,t in enumerate(tokens)}

id_to_token = {i:t for i,t in enumerate(tokens)}

#Cast everything from symbols into identifiers
corpora_ids = [token_to_id[elem] for elem in corpora]

# %%
def sample_random_batches(source,n_batches=10, seq_len=20):
    """
    This function should take random subsequences from the tokenized text.

    Parameters:
        source - basicly, what you have just computed in the corpora_ids variable
        n_batches - how many subsequences are to be sampled
        seq_len - length of each of such subsequences
          
    You have to return:
     X - a matrix of int32 with shape [n_batches,seq_len]
        Each row of such matrix must be a subsequence of source 
            starting from random index of corpora (from 0 to N-seq_len-2)
     Y - a vector, where i-th number is one going RIGHT AFTER i-th row from X from source
     
     Thus sample_random_batches(corpora_ids, 25, 10) must return
         X, X.shape == (25,10),  X.dtype == 'int32'
             where each row is a 10-character-id subsequence from corpora_ids
         Y, Y.shape == (25,), Y.dtype == 'int32'
             where each element is 11-th element to the corresponding 10-symbol sequence from X
    
    PLEASE MAKE SURE that y symbols are indeed going immediately after X sequences, 
        since it is hard to debug later (NN will train, but it will generate something useless)
        
    The simplest approach is to first sample a matrix [n_batches, seq_len+1] 
        and than split it into X (first seq_len columns) and y (last column)

    There will be some tests for this function, but they won't cover everything
    """ 
    X_batch = []
    y_batch = []
    for i in range(n_batches):
        el = np.random.randint(0, len(source)-seq_len -2)
        x = source[el: el+seq_len]
        y = source[el+seq_len]
        X_batch.append(x)
        y_batch.append(y)
    return X_batch, y_batch

# %% [markdown]
# # Constants

# %%
#Training sequence length (truncation depth in BPTT)
seq_length = 10
#better start small (e.g. 5) and increase after the net learned basic syllables. 10 is by far not the limit.

#max gradient between recurrent layer applications (do not forget to use it)
grad_clip = 100

# %% [markdown]
# # Input variables

# %%
input_sequence = T.matrix('input sequence','int32')
target_values = T.ivector('target y')

# %% [markdown]
# # Build the neural network
#
# You will need to define a neural network that processes a sequence of n tokens and outputs probabilities for n+1'st one.
#
# The default architecture pattern would be
#
#
# * Input
# * Input processing (embedding/1-hot)
# * Recurrent layer(s)
# * Slicing last state
# * Regular (e.g. dense) layers from last state
# * output layer that predicts probabilities of next token
#
#
#
#
#
# One way of data processing is to use an EmbeddingLayer (see previous seminar)
#
# Alternatively, one could use a One-hot encoder
# ```
# #One-hot encoding sketch
# def to_one_hot(seq_matrix):
#
#     input_ravel = seq_matrix.reshape([-1])
#     input_one_hot_ravel = T.extra_ops.to_one_hot(input_ravel,
#                                            len(tokens))
#     sh=input_sequence.shape
#     input_one_hot = input_one_hot_ravel.reshape([sh[0],sh[1],-1,],ndim=3)
#     return input_one_hot
#
# # Can be applied to input_sequence - and the l_in below will require a new shape
# # can also be used via ExpressionLayer(l_in, to_one_hot, shape_after_one_hot) - keeping l_in as it is
# ```
#
#
#
# To cut out the last RNN state, use one of those
# * `lasagne.layers.SliceLayer(rnn, -1, 1)`
# * only_return_final=True in RNN params

# %%
from lasagne.layers import InputLayer,DenseLayer,EmbeddingLayer
from lasagne.layers import RecurrentLayer,LSTMLayer,GRULayer,CustomRecurrentLayer

# %%
l_in = lasagne.layers.InputLayer(shape=(None, None),input_var=input_sequence)

l_emb = lasagne.layers.EmbeddingLayer(l_in, len(tokens), len(tokens))

l_rnn = lasagne.layers.RecurrentLayer(l_emb, 256)

l_rnn = lasagne.layers.RecurrentLayer(l_rnn, 256, only_return_final=True)

l_out = lasagne.layers.DenseLayer(l_rnn, len(tokens), nonlinearity=lasagne.nonlinearities.softmax)

# %%
# Model weights
weights = lasagne.layers.get_all_params(l_out,trainable=True)
print weights
# Out:
# [W, input_to_hidden.W, input_to_hidden.b, hidden_to_hidden.W, input_to_hidden.W, input_to_hidden.b, hidden_to_hidden.W, W, b]

# %%
network_output = lasagne.layers.get_output(l_out)
#If you use dropout do not forget to create deterministic version for evaluation

# %%
loss = lasagne.objectives.categorical_crossentropy(network_output,target_values).mean()

updates = lasagne.updates.adam(loss,weights)

# %% [markdown]
# # Compiling it

# %%
#training
train = theano.function([input_sequence, target_values], loss, updates=updates, allow_input_downcast=True)

#computing loss without training
compute_cost = theano.function([input_sequence, target_values], loss, allow_input_downcast=True)

# next character probabilities
probs = theano.function([input_sequence],network_output,allow_input_downcast=True)

# %% [markdown]
# # Law generation
#
# * We shall repeatedly apply NN to it's output.
#  * Start with some sequence of length <seq length>
#  * call probs(that sequence)
#  * choose next symbol based on probs
#  * append it to the sequence
#  * remove the 0-th symbol so that it's length equals <seq length> again
#
# * There are several policies of character picking
#  * random, proportional to the probabilities
#  * only take the one with highest probability
#  * random, proportional to softmax(probas*alpha), where alpha is "greed" (from 0 to infinity)

# %%
def max_sample_fun(probs):
    """i generate the most likely symbol"""
    return np.argmax(probs) 

def proportional_sample_fun(probs):
    """i generate the next int32 character id randomly, proportional to probabilities
    
    probs - array of probabilities for every token
    
    you have to output a single integer - next token id - based on probs
    """
    a = np.arange(0, len(tokens))
    chosen_token = np.random.choice(a ,p = probs)
    return chosen_token

# %%
def generate_sample(sample_fun,seed_phrase=None,N=200):
    '''
    The function generates text given a phrase of length at least SEQ_LENGTH.
        
    parameters:
        sample_fun - max_ or proportional_sample_fun or whatever else you implemented
        
        The phrase is set using the variable seed_phrase

        The optional input "N" is used to set the number of characters of text to predict.     
    '''

    if seed_phrase is None:
        start = np.random.randint(0,len(corpora)-seq_length)
        seed_phrase = corpora[start:start+seq_length]
        print "Using random seed:",seed_phrase
    while len(seed_phrase) < seq_length:
        seed_phrase = " "+seed_phrase
    if len(seed_phrase) > seq_length:
        seed_phrase = seed_phrase[len(seed_phrase)-seq_length:]
    assert type(seed_phrase) is unicode
        
        
    sample_ix = []
    x = map(lambda c: token_to_id.get(c,0), seed_phrase)
    x = np.array([x])

    for i in range(N):
        # Pick the character that got assigned the highest probability
        ix = sample_fun(probs(x).ravel())
        # Alternatively, to sample from the distribution instead:
        # ix = np.random.choice(np.arange(vocab_size), p=probs(x).ravel())
        sample_ix.append(ix)
        x[:,0:seq_length-1] = x[:,1:]
        x[:,seq_length-1] = 0
        x[0,seq_length-1] = ix 

    random_snippet = seed_phrase + ''.join(id_to_token[ix] for ix in sample_ix)    
    print("----\n %s \n----" % random_snippet)

# %% [markdown]
# # Model training
#
# Here you can tweak parameters or insert your generation function
#
#
# __Once something word-like starts generating, try increasing seq_length__

# %%
print("Training ...")

#total N iterations
n_epochs=100

# how many minibatches are there in the epoch 
batches_per_epoch = 1000

#how many training sequences are processed in a single function call
batch_size=100

for epoch in xrange(n_epochs):

    print "Text generated proportionally to probabilities"
    generate_sample(proportional_sample_fun,None)
    
    print "Text generated by picking most likely letters"
    generate_sample(max_sample_fun,None)

    avg_cost = 0;
    
    for _ in range(batches_per_epoch):
        
        x,y = sample_random_batches(corpora_ids,batch_size,seq_length)
        avg_cost += train(x, y)
        
    print("Epoch {} average loss = {}".format(epoch, avg_cost / batches_per_epoch))
# Out:
# Training ...
# Text generated proportionally to probabilities
# Using random seed: тных средс
# ----
# V„Т
# рж:лЕ,;Мбсз“П4юуфя§(cЖ»иИУЛш§
# й-6Ор@С1@'чГЧ№/ухГш/ЗПI„/'ш–НИЗ(Й'2;6ЯЩ„cуиз 8ЩмPк"ъл,Ощъ2Ч0!
# 7а%ЯуЯсV"' Дй(в“Ч:уР4ы Ц;.ХРхщуЫ%кЙьз)cО»Цтш;уу+ЦМЫ7c:Д
# 'хуть+РЕтБдыф
# ----
# Text generated by picking most likely letters
# Using random seed: льств, а т
# ----
#  льств, а т©©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИЛ©йУИ
# ----
# Epoch 0 average loss = 2.82757029808
# Text generated proportionally to probabilities
# Using random seed: – другим д
# ----
#  – другим ды вении нель срекенита зенуты итичоние их окракие, ерматноголуна дей; заслернете, гратувед свкаж ос слгащениймьеднеглиста спуд аслайта имраю сплатранные плеота кадполетьесле перара тенстенай. у) вей)
# ----
# Text generated by picking most likely letters
# Using random seed:  оплаты тр
# ----
#   оплаты традение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прадение прад
# ----
# Epoch 1 average loss = 2.08850223541
# Text generated proportionally to probabilities
# Using random seed: аможенного
# ----
#  аможенного абзаз 1187 Предедальнои од квемене ичихаести дыхущества, налогоот плести тануне седуаственности очубта тамущеских м реоов лица успотст ослачии детовущее поотнодения плете 80 55, в заковенанах предола
# ----
# Text generated by picking most likely letters
# Using random seed: ества
#
#
# ----
#  ества
#
#  Статья 19.
#  1. Пределание предела предела предела предела предела предела предела предела предела предела предела предела предела предела предела предела предела предела предела предела предела преде
# ----
# Epoch 2 average loss = 1.67313977914
# Text generated proportionally to probabilities
# Using random seed: оящего Код
# ----
#  оящего Кодекса, права исполнения оскать прове ины, предусмотренные акмоновлен в плятеском.
#  Осли сматрено делу обе предусмотренными фогтвенственнох скответственнуя жил госудержиется тойне судерных в раговрежен
# ----
# Text generated by picking most likely letters
# Using random seed: смотрения
# ----
#  смотрения предусмотренных правонарушения предусмотренных правонарушения предусмотренных правонарушения предусмотренных правонарушения предусмотренных правонарушения предусмотренных правонарушения предусмотренны
# ----
# Epoch 3 average loss = 1.45794548607
# Text generated proportionally to probabilities
# Using random seed: ть и выпла
# ----
#  ть и выплатернего умантивиех водовытного нед обершения. 3.
#  0. Не-наовор доставлено мерера сумм инии ыли по имунногогоморов;
#  3. Лицум.
#  7) вывозу
#
#  1. стрования о судом.
#  4. возмере мазейском миницательс
# ----
# Text generated by picking most likely letters
# Using random seed: ия оружия
# ----
#  ия оружия не производством судов оплаты труда;
#  2. Правонарушения и производством судов оплаты труда;
#  2. Правонарушения и производством судов оплаты труда;
#  2. Правонарушения и производством судов оплаты тр
# ----
# Epoch 4 average loss = 1.3451543849
# Text generated proportionally to probabilities
# Using random seed: дусмотренн
# ----
#  дусмотренным вонмаства, должностными лино государственной не продивия пристьют залогов, применяющуе , побчего должностных лиц, в товий товаров случающими соответствующее таможенные могсти путву наресяющей, суда
# ----
# Text generated by picking most likely letters
# Using random seed: ажного реш
# ----
#  ажного решения в соответствии с принятие по представить принятие по представить принятие по представить принятие по представить принятие по представить принятие по представить принятие по представить принятие п
# ----
# Epoch 5 average loss = 1.27613974654
# Text generated proportionally to probabilities
# Using random seed: ое средств
# ----
#  ое средства, удостоверным арендаружается сорехого оккаравших товька лигимарии впровехса согом об осустания государственнов докуда от статьи 1втожные средств, страховких посудаче имеров осуществляет договора, а
# ----
# Text generated by picking most likely letters
# Using random seed: ов в поряд
# ----
#  ов в порядке настоящим Кадебного законом и дела и обязанности и обязательства и обязанности и обязательства и обязанности и обязательства и обязанности и обязательства и обязанности и обязательства и обязанност
# ----
# Epoch 6 average loss = 1.23126636391
# Text generated proportionally to probabilities
# Using random seed: тия непокр
# ----
#  тия непокредниками, нная отпуска влечет предусмотренных установленноса
#
#  1. Невозникация, для предрехсимуется в ред. Фезопола договору о со днят, уполникается порудана, движения заключие м заведаниях) авминис
# ----
# Text generated by picking most likely letters
# Using random seed: ве без пре
# ----
#  ве без предусмотренных правонарушениях с принятия правонарушениях с принятия правонарушениях с принятия правонарушениях с принятия правонарушениях с принятия правонарушениях с принятия правонарушениях с приняти
# ----
# Epoch 7 average loss = 1.19387930838
# Text generated proportionally to probabilities
# Using random seed:  статьи 9.
# ----
#   статьи 9.47, Передать трех специального права трету, действия.
#  Вправление доседа соглюшениях свыденной обязательскый децены в решениям, возей.
#
#  Статье 251.
#  Нли спостров, с котого действий, если в гругим
# ----
# Text generated by picking most likely letters
# Using random seed: ных размер
# ----
#  ных размеров оплаты труда Российской Федерации и статье 10.12, 10.12.2004 №11-ФЗ)
#  2. При статье 10.12, 10.12.2004 №11-ФЗ)
#  2. При статье 10.12, 10.12.2004 №11-ФЗ)
#  2. При статье 10.12, 10.12.2004 №11-ФЗ)
# ----
# Epoch 8 average loss = 1.16766391428
# Text generated proportionally to probabilities
# Using random seed: ения, по п
# ----
#  ения, по передавает воездар перед таможенных пошлин, помещенией;
#  возначание, помещение обязанией кружанное местный есле
#
#  1. Обоза жело, арендательских в случае выболдение (его установленных в случая долю с
# ----
# Text generated by picking most likely letters
# Using random seed: х размеров
# ----
#  х размеров оплаты труда.
#  2. При осуществление или пользование и должно быть получение постановление и пользование и должно быть получение постановление и пользование и должно быть получение постановление и по
# ----
# Epoch 9 average loss = 1.15245192529
# Text generated proportionally to probabilities
# Using random seed: . Кассацио
# ----
#  . Кассационных правоназ сыстека. настоящего Сумых разостов реда государств производственной признается застектве пресятидекству), Федерации в комирских истеченных а также судьк, конфизкации освидетельствам бует
# ----
# Text generated by picking most likely letters
# Using random seed: сли такой
# ----
#  сли такой собственности и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия
# ----
# Epoch 10 average loss = 1.13552699109
# Text generated proportionally to probabilities
# Using random seed: е непредст
# ----
#  е непредставленные похрежному гражданано указанный проектов с подавения соответственно-террет свободнык огзаво разрабой доступает должностными вправе частам разкальников и остальные сдракском сиши лиц
#
#  Нарбо
# ----
# Text generated by picking most likely letters
# Using random seed: е после то
# ----
#  е после товаров и образование производстве продава в соответствующих в соответствующих в соответствующих в соответствующих в соответствующих в соответствующих в соответствующих в соответствующих в соответствующ
# ----
# Epoch 11 average loss = 1.11734646739
# Text generated proportionally to probabilities
# Using random seed: быть подчи
# ----
#  быть подчиняет их посуса в случае живона от перинтизе.
#  3. Пребования лица взальной ремелы учевником правонарушения;
#  4) помещения Чиних не условий, денежных договором опушко в соответствии с объектами; предп
# ----
# Text generated by picking most likely letters
# Using random seed: иобрести л
# ----
#  иобрести либо по пределами или по пределами или по пределами или по пределами или по пределами или по пределами или по пределами или по пределами или по пределами или по пределами или по пределами или по предел
# ----
# Epoch 12 average loss = 1.1014334268
# Text generated proportionally to probabilities
# Using random seed: ждении и п
# ----
#  ждении и пократиться приныл включается опоавших ненадзов, уполномочие органа в Рлзми специальные разимостоят просерского ьград рассматриваемых сбойся лицом.
#  3. В месъок, исчести, лино страховать подрядчико, п
# ----
# Text generated by picking most likely letters
# Using random seed:  на них об
# ----
#   на них образования и договора и договора и договора и договора и договора и договора и договора и договора и договора и договора и договора и договора и договора и договора и договора и договора и договора и д
# ----
# Epoch 13 average loss = 1.08457334589
# Text generated proportionally to probabilities
# Using random seed: авить отзы
# ----
#  авить отзывы в Вспальные условиями или засаде, пользование ходатайств правовых граждан в пурендии), предусмотренных докадет, а также бладовций лицами, противодательских срока, до ним э сходдающиц доводе застоящ
# ----
# Text generated by picking most likely letters
# Using random seed: приставом
# ----
#  приставом или в случаях правовым правонарушения и принятия правонарушения и принятия правонарушения и принятия правонарушения и принятия правонарушения и принятия правонарушения и принятия правонарушения и прин
# ----
# Epoch 14 average loss = 1.0924913169
# Text generated proportionally to probabilities
# Using random seed: . При разд
# ----
#  . При раздельных здоровать исполнинить остального судь обы перевозки милиции товары, проветдельников меделафий.
#  2. Если обстоятельства.
#
#  Статья 9126. Исполляционность, при права в этента исключения определ
# ----
# Text generated by picking most likely letters
# Using random seed: паривается
# ----
#  паривается применения исполнения и применения исполнения и применения исполнения и применения исполнения и применения исполнения и применения исполнения и применения исполнения и применения исполнения и примене
# ----
# Epoch 15 average loss = 1.06543953732
# Text generated proportionally to probabilities
# Using random seed:  от тридца
# ----
#   от тридцатиднях последних статьи, и и их выбода сооружительной выноси.
#  ним воорговой меростивно-пунктом целью или и жалое, немоно вступуют послуждении наследование переданных из нем дела, и ответственность,
# ----
# Text generated by picking most likely letters
# Using random seed: рак и в др
# ----
#  рак и в других лиц – от пятнадцати минимальных размеров оплаты труда; на должностных лиц – от пятнадцати минимальных размеров оплаты труда; на должностных лиц – от пятнадцати минимальных размеров оплаты труда;
# ----
# Epoch 16 average loss = 1.06191616152
# Text generated proportionally to probabilities
# Using random seed: связано с
# ----
#  связано с возмещение орган уполномоченному определяются имущественныму арбитражный разимателем.
#  При емусбор имею действие допускается.
#
#  Сторон предупредельми за матера совершениисъемии, покорпликаций;
#  5)
# ----
# Text generated by picking most likely letters
# Using random seed: ед. Федера
# ----
#  ед. Федерального законом или при применения при применения при применения при применения при применения при применения при применения при применения при применения при применения при применения при применения п
# ----
# Epoch 17 average loss = 1.05675698385
# Text generated proportionally to probabilities
# Using random seed: праве ссыл
# ----
#  праве ссыла в порядке в случае сжительным волиыся эрожной воднике.
#  3. Недминимальных размеров оплаты труда; на юдидизы в использовать каторы о выпа исмотросное принытых средствами или дело, сообщие законы.
#
# ----
# Text generated by picking most likely letters
# Using random seed: ении факта
# ----
#  ении фактами 1 статьи 19.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2, 11.17, 20.2,
# ----
# Epoch 18 average loss = 1.05401663787
# Text generated proportionally to probabilities
# Using random seed: ны, уполно
# ----
#  ны, уполном статья.
#  Рассматривает деведоприяний.
#  Ласчит контритула прошедения располральными представлении операнию данных в уплаты в наимена, чтобу предприятий.
#
#  Статья 24.
#  Информацию принятием или и
# ----
# Text generated by picking most likely letters
# Using random seed: ство должн
# ----
#  ство должностных лиц – от десяти минимальных размеров оплаты труда; на должностных лиц – от десяти минимальных размеров оплаты труда; на должностных лиц – от десяти минимальных размеров оплаты труда; на должнос
# ----
# Epoch 19 average loss = 1.04612975755
# Text generated proportionally to probabilities
# Using random seed: обязательс
# ----
#  обязательствами лица, вступом может препясшестей, Государственнае соответствующей и представитель решение имущество, цены, А таможенных организовать оргороченное страховому сей, на общество в соответствие свой
# ----
# Text generated by picking most likely letters
# Using random seed: Сторона, п
# ----
#  Сторона, принятие правонарушениях и принятие правонарушениях и принятие правонарушениях и принятие правонарушениях и принятие правонарушениях и принятие правонарушениях и принятие правонарушениях и принятие пра
# ----
# Epoch 20 average loss = 1.03997658465
# Text generated proportionally to probabilities
# Using random seed: вонарушени
# ----
#  вонарушения или правил обстоятельстве.
#  3. Ненадлежащем договора. принятие нассиейтевшего мировре с их ны в требования, продажа товаров и товаров и дня полученых привиоающей наео относительностью нерамодных пр
# ----
# Text generated by picking most likely letters
# Using random seed: анные в ст
# ----
#  анные в статья 1003.
#  При наследства или принятие прав по принятие прав по принятие прав по принятие прав по принятие прав по принятие прав по принятие прав по принятие прав по принятие прав по принятие прав п
# ----
# Epoch 21 average loss = 1.03535925193
# Text generated proportionally to probabilities
# Using random seed: бществом с
# ----
#  бществом сведения во в соответствии с производстве, уживошившности убытковсе (статья 533.
#  Объев, Гоставленные или результатам.
#
#
#  (в этой, по ходатайств и рассмотрения или налагы выекразные в увооровья.
#
# ----
# Text generated by picking most likely letters
# Using random seed: имых для п
# ----
#  имых для применяются в соответствии с наследство или иное не предусмотренных пошлин, налогов и подрядчик в соответствии с наследство или иное не предусмотренных пошлин, налогов и подрядчик в соответствии с насл
# ----
# Epoch 22 average loss = 1.03585813339
# Text generated proportionally to probabilities
# Using random seed: 1. Если им
# ----
#  1. Если ими товари до пятнадцати чису-щае их местора предстовления в договором собственности и ввоза минимальных размеров,данием случаев использовании, состоятельных признаниом в случае не должение) предпринима
# ----
# Text generated by picking most likely letters
# Using random seed: отивления
# ----
#  отивления по делу об административного штрафа на гражданина обязан предусмотренных законности подача подача подача подача подача подача подача подача подача подача подача подача подача подача подача подача пода
# ----
# Epoch 23 average loss = 1.02660827502
# Text generated proportionally to probabilities
# Using random seed: , налогов,
# ----
#  , налогов, опоста, совершений решения о прокурайного обязана с органе находящихся в отнощелссмонного проведенной жалобы и Российской Федерации но относится и товара новой) решения, наказшок, рассматривается фор
# ----
# Text generated by picking most likely letters
# Using random seed: нтов в соо
# ----
#  нтов в соответствии с применения или иное не предусмотренных дела об административного правонарушениях, предусмотренных дела об административного правонарушениях, предусмотренных дела об административного право
# ----
# Epoch 24 average loss = 1.02090000701
# Text generated proportionally to probabilities
# Using random seed: додателя о
# ----
#  додателя обстоятельств, вправе в случаях, которых средства сам, территории месяцам товаров, – на которых для ввезенном фондовые замедений за производимы в соответствии товарищестных лиц – от пяти его исполнител
# ----
# Text generated by picking most likely letters
# Using random seed: определяет
# ----
#  определяется в случае не предусмотрено законом или иностранного состава и принятия правила от принятия правила от принятия правила от принятия правила от принятия правила от принятия правила от принятия правила
# ----
# Epoch 25 average loss = 1.01781831862
# Text generated proportionally to probabilities
# Using random seed: выбору орг
# ----
#  выбору органи с их нарушения в пунктом деремил выдают использоваться лицу, отозиса
#
#  Полагориосу
#
#  1. который формлении оперативной условий должностных лицо) под таможенный органов. если оперативном средств
# ----
# Text generated by picking most likely letters
# Using random seed: трахованно
# ----
#  трахованного права по делу об административного штрафа на граждан в размере от двадцати минимальных размеров оплаты труда; на юридического лица по делу об административного штрафа на граждан в размере от двадца
# ----
# Epoch 26 average loss = 1.01509504571
# Text generated proportionally to probabilities
# Using random seed:  орган, пр
# ----
#   орган, приостановлении общей счет вправе принимается сейупостановие, остановки, рорминодателя цез тачих частью 1 настоящего Кадел;
#  транспортных средств, проведению в Предусмотрено защать комиссия, которыми,
# ----
# Text generated by picking most likely letters
# Using random seed: ат участни
# ----
#  ат участников и обоснования и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности
# ----
# Epoch 27 average loss = 1.00734951467
# Text generated proportionally to probabilities
# Using random seed: попечитель
# ----
#  попечительно в отношении обеспечения ос авиомы в результата входящим за нарушения или уставовой стране разнаков полностью свободных обнараний;
#  средитных вреда страховяе банку
#
#  Порразом представителем, ресу
# ----
# Text generated by picking most likely letters
# Using random seed: ровью, не
# ----
#  ровью, не предусмотренных статьями 19.26, частью 1 статьи 19.26, частью 1 статьи 19.26, частью 1 статьи 19.26, частью 1 статьи 19.26, частью 1 статьи 19.26, частью 1 статьи 19.26, частью 1 статьи 19.26, частью
# ----
# Epoch 28 average loss = 1.01331708219
# Text generated proportionally to probabilities
# Using random seed:  с явкой в
# ----
#   с явкой выкакой об оспаривающееся лидность и потаний
#
#  Положение исследодателем обеспечению услуг доварищественного им предоставляется статья 3. При строительством, которает с отсутствии которыми об эбиранен
# ----
# Text generated by picking most likely letters
# Using random seed: рг те или
# ----
#  рг те или иной производства, предусмотренных статьей 250 настоящего Кодекса.
#  2. При принятия подлежащим правонарушениях, предусмотренных статьей 250 настоящего Кодекса.
#  2. При принятия подлежащим правонаруш
# ----
# Epoch 29 average loss = 1.01082032976
# Text generated proportionally to probabilities
# Using random seed: во новому
# ----
#  во новому при неотношения излицных цилесть определяются вместиямости законом испоциалы совершенных предоставлены в пользователям в принятых располное должника с ограничения и таможенных подг режуми на такики
#
# ----
# Text generated by picking most likely letters
# Using random seed: главе не п
# ----
#  главе не предусмотренном законом или не предусмотренном законом или не предусмотренном законом или не предусмотренном законом или не предусмотренном законом или не предусмотренном законом или не предусмотренном
# ----
# Epoch 30 average loss = 0.999416854068
# Text generated proportionally to probabilities
# Using random seed: 2.2003 №16
# ----
#  2.2003 №162-ФЗ, от пяти лет под товарах по непосредственные надзора или договора и договором отпа деле, на истечения договор, пресечения транспортных средств менье о форекьа, в именворь лица в зонлабоиигицом до
# ----
# Text generated by picking most likely letters
# Using random seed: производст
# ----
#  производства и принятия подлежащим в соответствии с законодательством Российской Федерации и принятия подлежащим в соответствии с законодательством Российской Федерации и принятия подлежащим в соответствии с за
# ----
# Epoch 31 average loss = 0.995032987375
# Text generated proportionally to probabilities
# Using random seed: у c 6 авгу
# ----
#  у c 6 авгуанта в поеку производства индивиду атможых отправление в предоставляется в случаю деятельности, на вумоставляющие связы от 07.08.2004 №46-на-399-ФЗ-52, автономной госумартой.
#  3. За жилоственнить за
# ----
# Text generated by picking most likely letters
# Using random seed:  таможенны
# ----
#   таможенных органов и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и принятии и п
# ----
# Epoch 32 average loss = 1.00153219801
# Text generated proportionally to probabilities
# Using random seed: унктом 3 с
# ----
#  унктом 3 статьи 207), д.щДесакт.
#
#  Статья 865.
#  Опигательства о доказательств. Прощерены в месту шестирование.
#  5. Процесса игиры отдельных объектов по оферстические законы заседания такого обязательства в
# ----
# Text generated by picking most likely letters
# Using random seed: ного показ
# ----
#  ного показательств и пользования обязанности и пользования обязанности и пользования обязанности и пользования обязанности и пользования обязанности и пользования обязанности и пользования обязанности и пользов
# ----
# Epoch 33 average loss = 0.999133628294
# Text generated proportionally to probabilities
# Using random seed:  При этом
# ----
#   При этом застротовелести, которых основан имени требований в фили миловестить организации, осуществляющие уплаты призучительными судом подконодник от правонарушенинворных правовых аренды нормативных правонаруш
# ----
# Text generated by picking most likely letters
# Using random seed: е использо
# ----
#  е использования по делу об административного правонарушениях от пяти до десяти минимальных размеров оплаты труда.
#  2. При отсутствии с принятии правонарушениях от пяти до десяти минимальных размеров оплаты тру
# ----
# Epoch 34 average loss = 0.993210808728
# Text generated proportionally to probabilities
# Using random seed: полнительн
# ----
#  полнительно принятии, свидетель осуществленных дела независимо от имени право от 20.02.2003 №82-ФЗ).
#  Или и ходатайство вещь, печати они от соблюжения на ее 19.4, члебования.
#  Об авторсиях, не перебезения для
# ----
# Text generated by picking most likely letters
# Using random seed: итражном с
# ----
#  итражном суд и об обязанности по принятия по принятия по принятия по принятия по принятия по принятия по принятия по принятия по принятия по принятия по принятия по принятия по принятия по принятия по принятия
# ----
# Epoch 35 average loss = 0.993010669
# Text generated proportionally to probabilities
# Using random seed: яющийся до
# ----
#  яющийся договор. Если вещи
#
#  Ограничением или намерения, если закеннного) знипа и правилопсленити не апелляционного государственных в законной Дониции товарам предусмотренными месте предупрежда по поданные пр
# ----
# Text generated by picking most likely letters
# Using random seed:  и техниче
# ----
#   и техническое лицо, причитаются предусмотренных получение права и причитаются предусмотренных получение права и причитаются предусмотренных получение права и причитаются предусмотренных получение права и причи
# ----
# Epoch 36 average loss = 0.987553260975
# Text generated proportionally to probabilities
# Using random seed: ального за
# ----
#  ального законом, законом надзеса со следующих зна не ввокы удостоверено взнода.
#  Предметным в совершает при нахожяются направляется по лица, кру место быть формы и кне даранного граждан, в образе в после перед
# ----
# Text generated by picking most likely letters
# Using random seed: аможенную
# ----
#  аможенную границу в соответствии с законодательством Российской Федерации и представителя и представителя и представителя и представителя и представителя и представителя и представителя и представителя и предст
# ----
# Epoch 37 average loss = 0.988434755338
# Text generated proportionally to probabilities
# Using random seed: ом неуважи
# ----
#  ом неуважисци на нефедетанствы второй прибору транспортного средство и правилам превышающий престирательство управляющие передома.
#  Определи имущества, а также использовать здания договор на округнольния или о
# ----
# Text generated by picking most likely letters
# Using random seed: ы человека
# ----
#  ы человека и принятия предусмотренных статьями 19.1, частью 1 статьи 12.1 настоящего Кодекса.
#  2. При обязан предусмотренных статьями 19.1, частью 1 статьи 12.1 настоящего Кодекса.
#  2. При обязан предусмотрен
# ----
# Epoch 38 average loss = 0.986787118634
# Text generated proportionally to probabilities
# Using random seed: ории Росси
# ----
#  ории Российского лица, пользователя запрещения приобретшими наследник, что соответствии с совершении не достоверно, приобрелеля.
#  7. При отсутствии ли, иного узия завещании.
#  4. Незакимавии, индектитат, в соо
# ----
# Text generated by picking most likely letters
# Using random seed: ственная р
# ----
#  ственная решения или договора или договора или договора или договора или договора или договора или договора или договора или договора или договора или договора или договора или договора или договора или договор
# ----
# Epoch 39 average loss = 0.99218803933
# Text generated proportionally to probabilities
# Using random seed: определени
# ----
#  определению.
#  16. Правомоченного международной международных трех для пригодоприентросной) может в засестрой индивидуального обрарование помебнику лицу, сдакувленных порядок собантов. Продажимальной декствием,
# ----
# Text generated by picking most likely letters
# Using random seed: д таможенн
# ----
#  д таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную таможенную
# ----
# Epoch 40 average loss = 0.987087252415
# Text generated proportionally to probabilities
# Using random seed: ию запроса
# ----
#  ию запроса недостей.
#
#  Статья 431.
#  Взыскатель ферераличным законом, по установленного настоящем органы в том мофищестили или наимущестивном заявленных гражданам) и раскраждения, выполнение требования
#
#  1.
# ----
# Text generated by picking most likely letters
# Using random seed: ешается во
# ----
#  ешается возмещения или иное не предусмотренных статьей 11.12, часть принятых право на таможенных пошлин, налогов и принятых право на таможенных пошлин, налогов и принятых право на таможенных пошлин, налогов и п
# ----
# Epoch 41 average loss = 0.988966900054
# Text generated proportionally to probabilities
# Using random seed: вить возмо
# ----
#  вить возможно причеления. Нарушение котором товары за исконные срок.
#
#  137.
#  8. Удовлетвария сдовыер работы го завещание (рабочого при привлеченных завнодникам при свой оспортанной собствятелей. Ом разрешает
# ----
# Text generated by picking most likely letters
# Using random seed: анию, или
# ----
#  анию, или обязан в соответствии с настоящим Кодексом и при отсутствие в соответствии с настоящим Кодексом и при отсутствие в соответствии с настоящим Кодексом и при отсутствие в соответствии с настоящим Кодексо
# ----
# Epoch 42 average loss = 0.983657656024
# Text generated proportionally to probabilities
# Using random seed: договором.
# ----
#  договором. Очередного управления закон условия строительством Российской Федерации о однастсяюо моменту долы на склада или его постановления несовершенное кассационной форме, судом за привлеченные предъявить гр
# ----
# Text generated by picking most likely letters
# Using random seed: я, содержа
# ----
#  я, содержания по договоре по договоре по договоре по договоре по договоре по договоре по договоре по договоре по договоре по договоре по договоре по договоре по договоре по договоре по договоре по договоре по д
# ----
# Epoch 43 average loss = 0.982785648512
# Text generated proportionally to probabilities
# Using random seed: овора, сог
# ----
#  овора, согдвую предметей, в течение предприятия подлежит, вместе долга этих которой только лицах) из вопроса или договора уплачителем по ему считартного выданной фондодорца.
#  Во взыскакий лиц, позучемх 2403) л
# ----
# Text generated by picking most likely letters
# Using random seed: ых данных)
# ----
#  ых данных) представления и принятия представления и принятия представления и принятия представления и принятия представления и принятия представления и принятия представления и принятия представления и принятия
# ----
# Epoch 44 average loss = 0.976972139265
# Text generated proportionally to probabilities
# Using random seed: одлежит ра
# ----
#  одлежит растеное откущения ободы или в том числе и место в случаях, предусмотрено законом.
#  1. Представления в сведений, подлививатами. После условий ограничения животного винов объектов.
#  7. По заклоком не п
# ----
# Text generated by picking most likely letters
# Using random seed: же приложе
# ----
#  же приложении и об обслуживание при принятия на основаниям и об обслуживание при принятия на основаниям и об обслуживание при принятия на основаниям и об обслуживание при принятия на основаниям и об обслуживани
# ----
# Epoch 45 average loss = 0.989611655475
# Text generated proportionally to probabilities
# Using random seed: иниматься
# ----
#  иниматься соответствии с приклоков ее владельца. Нацир, средств. Не входящих передачи рассмотрения управлении или усылается возмещаетыю невыполнения к которое отказователь представления товаров в отношении неса
# ----
# Text generated by picking most likely letters
# Using random seed: иоративных
# ----
#  иоративных правонарушениях, предусмотренных статьями 11.12 настоящей статьи и принятие по делу об административного штрафа на должностных лиц в размере 1 или иных права и принятие по делу об административного ш
# ----
# Epoch 46 average loss = 0.981825338579
# Text generated proportionally to probabilities
# Using random seed: не докажет
# ----
#  не докажет одновращности убытии за контрагист), представление должника по сведения, на превышать от имени докукина было выполнения;
#  58. Нормалной одит с договора по использование для требования;
#  3) лицам ра
# ----
# Text generated by picking most likely letters
# Using random seed: нами доказ
# ----
#  нами доказательства или иных правил или иных правил или иных правил или иных правил или иных правил или иных правил или иных правил или иных правил или иных правил или иных правил или иных правил или иных прави
# ----
# Epoch 47 average loss = 0.969436385728
# Text generated proportionally to probabilities
# Using random seed: е допускае
# ----
#  е допускается с таможенную не ответчик в письменного пользования обычей когда прикотавитель), препятство подряда о возместитационерым заместивает которых апелляционное процедурор принимать акце свидетелей.
#
#
# ----
# Text generated by picking most likely letters
# Using random seed: чения срок
# ----
#  чения срока по делу об административного штрафа на должностных лиц – от пятидесяти до пятнадцати лет и по право на получить право на получить право на получить право на получить право на получить право на получ
# ----
# Epoch 48 average loss = 0.975305413348
# Text generated proportionally to probabilities
# Using random seed: ваний, пре
# ----
#  ваний, предупрещении до денежным к через завещания работы, вправе в соответствии с отгр зашития, гарансе и сриземог исполнении неего правоворлена
#
#  Картитов исзуда, вынеси рапимеиюой, правопреевый Спись поряд
# ----
# Text generated by picking most likely letters
# Using random seed: уда; на юр
# ----
#  уда; на юридических лиц – от десяти до двадцати минимальных размеров оплаты труда; на юридических лиц – от десяти до двадцати минимальных размеров оплаты труда; на юридических лиц – от десяти до двадцати минима
# ----
# Epoch 49 average loss = 0.966187491623
# Text generated proportionally to probabilities
# Using random seed: кументы, ц
# ----
#  кументы, ценумуплентами впрузодоречена уголовности фимилие в ред. Федерального закове судьей, ответственностью действия, вознаграждения, принимает от их страхования, также третейского размер бДим
#
#
#  После де
# ----
# Text generated by picking most likely letters
# Using random seed:  без таков
# ----
#   без таковой или договором принятия на собственность при отсутствии с право предусмотренных настоящим Кодексом и обязанности при отсутствии с право предусмотренных настоящим Кодексом и обязанности при отсутстви
# ----
# Epoch 50 average loss = 0.964730735096
# Text generated proportionally to probabilities
# Using random seed: дополнител
# ----
#  дополнительных вещей, записанных на срока
#  332.
#
#  Статья 12.
#  18. Наядлять форменсе.
#  – нуго арбитражного суда или эти по этого по физические третьей, как вального правилами;
#  епляе в соответствии с част
# ----
# Text generated by picking most likely letters
# Using random seed: мущество в
# ----
#  мущество в соответствии с пункта 1 настоящей статьи, подлежащего приобретает предусмотренных статьей 299 настоящего Кодекса.
#  2. Несоблюдение или иного получение по правилами и по правилами и по правилами и по
# ----
# Epoch 51 average loss = 0.961203618248
# Text generated proportionally to probabilities
# Using random seed: вательного
# ----
#  вательного таможенную граниченном предоставитель, калены) Са попечительства Российской Федерации.
#   (июпать информационных в деле, другие членов к действия может за составляется в федеральный завещаний, являющ
# ----
# Text generated by picking most likely letters
# Using random seed: аров в меж
# ----
#  аров в международным статьями 19.6, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7,
# ----
# Epoch 52 average loss = 0.973714939462
# Text generated proportionally to probabilities
# Using random seed: асчета и р
# ----
#  асчета и разосродственные в нескольких лиц, нормы за за 20 действия, в том продавтронных завежениям на осуществляются по доволении исполняет другой документы аправляет пожизненного спора)
#
#  Даты выбора с кред
# ----
# Text generated by picking most likely letters
# Using random seed: рганов уго
# ----
#  рганов уголовного правонарушениях, предусмотрено договора по делу об административного правонарушениях, предусмотрено договора по делу об административного правонарушениях, предусмотрено договора по делу об адм
# ----
# Epoch 53 average loss = 0.969059556059
# Text generated proportionally to probabilities
# Using random seed: ление Конс
# ----
#  ление Конститладическое срока определения рревыл права.
#
#  Статья 853, 149 настоящей статьи, их рассматриван, явлениям, его пятидесяти минимальных размеров оплаты труда.
#  2. При таможенные пошлины, кабудь а и
# ----
# Text generated by picking most likely letters
# Using random seed: квартира,
# ----
#  квартира, применения права и обязанность производится в соответствии с настоящим Кодексом или обязанность производится в соответствии с настоящим Кодексом или обязанность производится в соответствии с настоящим
# ----
# Epoch 54 average loss = 0.971853911563
# Text generated proportionally to probabilities
# Using random seed: 3. Арбитра
# ----
#  3. Арбитражного суда может заключением случии по невето, находящей, считы в местшения и одного (неподтонсу других технических средств представляются закреторучитель жалобое явший в отношении таможенного складе
# ----
# Text generated by picking most likely letters
# Using random seed: правильное
# ----
#  правильное принятия права и принятия права и принятия права и принятия права и принятия права и принятия права и принятия права и принятия права и принятия права и принятия права и принятия права и принятия пра
# ----
# Epoch 55 average loss = 0.969559062494
# Text generated proportionally to probabilities
# Using random seed: уплаченные
# ----
#  уплаченные пункте унитарных изжет постановления в арбитражного суда Российской Федерации оружие Формы или по правилам
#
#  1. Об экспоокьй
#
#  1. Деятельности без акциека, определяются из досрочно-идминистром эт
# ----
# Text generated by picking most likely letters
# Using random seed: авать имущ
# ----
#  авать имущества и принятия предусмотренных настоящим Кодексом и принятия предусмотренных настоящим Кодексом и принятия предусмотренных настоящим Кодексом и принятия предусмотренных настоящим Кодексом и принятия
# ----
# Epoch 56 average loss = 0.966271171008
# Text generated proportionally to probabilities
# Using random seed: лномоченны
# ----
#  лномоченных убытки на должностных) матов в порядке наследниками последую порядки, подк на мер о сохраннику продажи товара, а отвела. После дела и доверения охраны ознаконных в других видах оперативных объезинем
# ----
# Text generated by picking most likely letters
# Using random seed: и 11.18, ч
# ----
#  и 11.18, частью 1 статьи 11.12, частью 1 статьи 11.12, частью 1 статьи 11.12, частью 1 статьи 11.12, частью 1 статьи 11.12, частью 1 статьи 11.12, частью 1 статьи 11.12, частью 1 статьи 11.12, частью 1 статьи 1
# ----
# Epoch 57 average loss = 0.96057638796
# Text generated proportionally to probabilities
# Using random seed: ей, опреде
# ----
#  ей, определения у государственный наклалуз, вятег сотрудников производства на установленной в ответственности принятии на пункта пассажирики постановлении граждании омнимотному главы 309, и вывозтк, в соответст
# ----
# Text generated by picking most likely letters
# Using random seed: ица органо
# ----
#  ица органов, принятия обязан в соответствии с пользования и принятии иных образования и принятии иных образования и принятии иных образования и принятии иных образования и принятии иных образования и принятии и
# ----
# Epoch 58 average loss = 0.96558978509
# Text generated proportionally to probabilities
# Using random seed:  вклада уд
# ----
#   вклада удостоверения вклад подаетных, другим раздел (статья 27.43 – 38 и 19.5, частью 3 и 2 статьи 292,.
#  Если отмене рулое постановления судов допудания экспедиров (сторонами судебными органам или если экспл
# ----
# Text generated by picking most likely letters
# Using random seed: граничения
# ----
#  граничения при отсутствии в соответствии с настоящим Кодексом и права на проведения обязанности и права на проведения обязанности и права на проведения обязанности и права на проведения обязанности и права на п
# ----
# Epoch 59 average loss = 0.963240606507
# Text generated proportionally to probabilities
# Using random seed: тивно, соб
# ----
#  тивно, собственных требование происшесков в часть, связанных с участок;
#  2) назначены в случая, имущество до трехсот минимальных размеров оплату таможенное порторовом других направна причитающего: 2 и исполуче
# ----
# Text generated by picking most likely letters
# Using random seed: ия.
#  5. Н
# ----
#  ия.
#  5. Наследства и применяются предусмотренных настоящим Кодексом и применяются предусмотренных настоящим Кодексом и применяются предусмотренных настоящим Кодексом и применяются предусмотренных настоящим Код
# ----
# Epoch 60 average loss = 0.963159406868
# Text generated proportionally to probabilities
# Using random seed: ии и СМВЧ
# ----
#  ии и СМВЧ и стоимости административного штрафаю не вмера.
#  2. Основе до установлены залогодей.
#  3) в распростране в составру печатама уплачивающим общеских предпринимателемом на основание недействия юридическ
# ----
# Text generated by picking most likely letters
# Using random seed: стему феде
# ----
#  стему федеральным законом или договора при принятия правила и при принятия правила и при принятия правила и при принятия правила и при принятия правила и при принятия правила и при принятия правила и при принят
# ----
# Epoch 61 average loss = 0.962165823303
# Text generated proportionally to probabilities
# Using random seed: ление, а т
# ----
#  ление, а также недвижимому изменения.
#
#  47 настоящей статьи – 309, 97 настоящего Кодекса оверения, одно валютить совершение, договорумы, меменстит и до протоколовым законов об этом некоммерческих органов пору
# ----
# Text generated by picking most likely letters
# Using random seed: рез своих
# ----
#  рез своих правил производства по делу об административного штрафа на граждан в размере от двадцати минимальных размеров оплаты труда; на юридических лиц – от двах должностных лиц – от двах должностных лиц – от
# ----
# Epoch 62 average loss = 0.960408438747
# Text generated proportionally to probabilities
# Using random seed: стности, я
# ----
#  стности, являются учреждения собой товарищество к действие и препятствии или цень в соответствии с на таможенных плателов, установлено документов, очереди
#
#  У. Права на реестр, чтоц на основания юридического
# ----
# Text generated by picking most likely letters
# Using random seed:  апелляцио
# ----
#   апелляционной жалобы при принятие на срок на должностных лиц – от десяти до двадцати минимальных размеров оплаты труда.
#
#  Статья 111.
#  Правительства или иных органов или от принятие на срок на должностных л
# ----
# Epoch 63 average loss = 0.955401629728
# Text generated proportionally to probabilities
# Using random seed: ном регули
# ----
#  ном регулирования сообщении о наличии и разрешания, а также установленном порядке созданность тридцати,дебиему постановки. , предметом касиника объявления средствами сута до 11 настоящего Кодекса.
#  Объекту 1 н
# ----
# Text generated by picking most likely letters
# Using random seed: еле, и выз
# ----
#  еле, и вызове предусмотренных статьей 19.14, статьей 19.14, статьей 19.14, статьей 19.14, статьей 19.14, статьей 19.14, статьей 19.14, статьей 19.14, статьей 19.14, статьей 19.14, статьей 19.14, статьей 19.14,
# ----
# Epoch 64 average loss = 0.962859567257
# Text generated proportionally to probabilities
# Using random seed: иц в разме
# ----
#  иц в размере, указанной отмененного вправе:
#  7) если будет области какия товара, по своим лицом баалисний, очереди, осуществления предитов днам лицу внимателя их их овещанных члении, и избранный законом, админ
# ----
# Text generated by picking most likely letters
# Using random seed: а временны
# ----
#  а временных при принятии при применения при применения при применения при применения при применения при применения при применения при применения при применения при применения при применения при применения при п
# ----
# Epoch 65 average loss = 0.953957926229
# Text generated proportionally to probabilities
# Using random seed:  производс
# ----
#   производство содержание протоколе о государственнония отправене другим лицом в месте и избирателей.
#
#  1. Них), убытков, предусмотренного поручения соглашение.
#  В случае, усилии, установлены, не расписквимо
# ----
# Text generated by picking most likely letters
# Using random seed: ется, если
# ----
#  ется, если он принявшихся при принятия право на таможенного органа и при принятия право на таможенного органа и при принятия право на таможенного органа и при принятия право на таможенного органа и при принятия
# ----
# Epoch 66 average loss = 0.967892365194
# Text generated proportionally to probabilities
# Using random seed:  некоторых
# ----
#   некоторых вкеняет фодексом нарушающим вины.
#
#  Статья 4.
#  6. Самовольные вещи в силу делу имущество,
#
#  Порядок независимо об уплаты которых быть направляют принять иностранный права, в выплаты учредительны
# ----
# Text generated by picking most likely letters
# Using random seed: ицам в соо
# ----
#  ицам в соответствии с праве на принятия право на принятия право на принятия право на принятия право на принятия право на принятия право на принятия право на принятия право на принятия право на принятия право на
# ----
# Epoch 67 average loss = 0.952100937931
# Text generated proportionally to probabilities
# Using random seed: ется произ
# ----
#  ется производства требованию нарушение тех лицом.
#  В случаях:
#  наклочнирые них выдачи другими разрешении обязанность цельных частью 1 статьи 397 (. Самостоятельной или иной фикиарров, создающееся с возмещению
# ----
# Text generated by picking most likely letters
# Using random seed: ным лицом
# ----
#  ным лицом и принятие наследства и принятие наследства и принятие наследства и принятие наследства и принятие наследства и принятие наследства и принятие наследства и принятие наследства и принятие наследства и
# ----
# Epoch 68 average loss = 0.960957936184
# Text generated proportionally to probabilities
# Using random seed: лезнодорож
# ----
#  лезнодорожной понесение лицам, которое мотивара или документов по договору имеют также организации без рассматривает в позирующего государственного сроков, предусмотрено договору реша, а досмотн в порядка иссле
# ----
# Text generated by picking most likely letters
# Using random seed: между кред
# ----
#  между кредитора и представителя и представителя и представителя и представителя и представителя и представителя и представителя и представителя и представителя и представителя и представителя и представителя и
# ----
# Epoch 69 average loss = 0.966143355461
# Text generated proportionally to probabilities
# Using random seed: движимости
# ----
#  движимости, определяются основа арбитражный суд утурзока и использование причинителей, ценалоги и его воспроизведенным отказ нахаденять заявления вступлению поставщикам хранение в отношении об овосодным долга в
# ----
# Text generated by picking most likely letters
# Using random seed: труда.
#  2
# ----
#  труда.
#  2. При применяются при признания и при признания и при признания и при признания и при признания и при признания и при признания и при признания и при признания и при признания и при признания и при пр
# ----
# Epoch 70 average loss = 0.951440578493
# Text generated proportionally to probabilities
# Using random seed: тоинства и
# ----
#  тоинства и груза.
#
#  Статья 899.
#  Обязатного товаров в сборесьи они банка, к мишившее в Российской Федерации не учредительным горучением.
#  О возрасте (бездействий, установление Президиуутов и разрешения суде
# ----
# Text generated by picking most likely letters
# Using random seed:  5. Подряд
# ----
#   5. Подрядчиком и при принятия об ответственностью и при условии и при принятия об ответственностью и при условии и при принятия об ответственностью и при условии и при принятия об ответственностью и при услови
# ----
# Epoch 71 average loss = 0.95502263272
# Text generated proportionally to probabilities
# Using random seed: ление деят
# ----
#  ление деятельность договором и иных актами.
#  наследуются и реголиках;
#  8) в неголькой. Меудитар, на ликвидация уплаченных лицу, направляется документарного средство изованка:
# ,, почтовой статей или отвечам и
# ----
# Text generated by picking most likely letters
# Using random seed: ления, нем
# ----
#  ления, немедленно принадлежащих право на области правила правила от представителя в соответствии с настоящим Кодексом и документов и общественных документов и общественных документов и общественных документов и
# ----
# Epoch 72 average loss = 0.957853100429
# Text generated proportionally to probabilities
# Using random seed: аждения во
# ----
#  аждения воспроизведений, заключения указанием вправе срока п-травая отказом, необходимые нужд, к нак мотрена окажетельный рассмотрения эксплуатации материальных актов, установленные и торгаю существующим в пред
# ----
# Text generated by picking most likely letters
# Using random seed: , своеврем
# ----
#  , своевременно в соответствии с законом или принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия п
# ----
# Epoch 73 average loss = 0.946910076803
# Text generated proportionally to probabilities
# Using random seed: меры, пред
# ----
#  меры, предупреда и пака) прицетное имеми ответственность предприятия, если иное.
#  4) не предусмотрена овмона. Таможен Обязан в обязанностей других оснований некополнения одействительности, говых договором, а р
# ----
# Text generated by picking most likely letters
# Using random seed: лжностных
# ----
#  лжностных лиц – от пятидесят при принятия право страхования и представителя и представителя и представителя и представителя и представителя и представителя и представителя и представителя и представителя и пред
# ----
# Epoch 74 average loss = 0.953869320994
# Text generated proportionally to probabilities
# Using random seed: нности; в
# ----
#  нности; в договоре лицо в этих статьей 1111 – 12нтариродной предупреждения в установленные в порядке, должны со дня зонвомехботоквиться в закрытых веществ
#
#  1. Документами.
#
#  Статья 25.
#  Принадлежавшиго, и
# ----
# Text generated by picking most likely letters
# Using random seed: еме МВД Ро
# ----
#  еме МВД Российской Федерации и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности
# ----
# Epoch 75 average loss = 0.954530686306
# Text generated proportionally to probabilities
# Using random seed: экономичес
# ----
#  экономическое условия стандартается из угользования экспорская природого месяционных исполучившим товары всегличедание дозерю;
#  5) соответствующий бааделяет на нужделжириществам, выпуска от ответственных спере
# ----
# Text generated by picking most likely letters
# Using random seed: установить
# ----
#  установить при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при принятия при
# ----
# Epoch 76 average loss = 0.955978785716
# Text generated proportionally to probabilities
# Using random seed: законодате
# ----
#  законодательством Российской Федерации не основание и коммерчек и организаций, соответствии с милоее проюктов;
#  5) для период капитальисбяти под признании иных лицом распространения одновременных после), уполн
# ----
# Text generated by picking most likely letters
# Using random seed:  том же пр
# ----
#   том же применения при применения при применения при применения при применения при применения при применения при применения при применения при применения при применения при применения при применения при примене
# ----
# Epoch 77 average loss = 0.953314269617
# Text generated proportionally to probabilities
# Using random seed: оба остава
# ----
#  оба оставама, взысканию либо рассмотрен исполняющие доказательства.
#
#  Статья 574.
#  Санкта.
#  2. 3, 8 статьи 67 настоящей главную собственное водды не после органов.
#  2. Земельных участное такое исчислениях,
# ----
# Text generated by picking most likely letters
# Using random seed: го оружия
# ----
#  го оружия или принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия и принятия
# ----
# Epoch 78 average loss = 0.957449268591
# Text generated proportionally to probabilities
# Using random seed:
#
#  Испол
# ----
#
#
#  Исполнять открытия административного хранителю сумму транспортным средского статьями 10.5, 11.7 настоящего Кодекса.
#   (бессеникам для назначаемый их в возражение к тересованное воде индущем одного рассмот
# ----
# Text generated by picking most likely letters
# Using random seed:  таможенно
# ----
#   таможенного контроля по договоре и положения или по принятия и положения или по принятия и положения или по принятия и положения или по принятия и положения или по принятия и положения или по принятия и положе
# ----
# Epoch 79 average loss = 0.950139298049
# Text generated proportionally to probabilities
# Using random seed: кций
#
#  1
# ----
#  кций
#
#  1. Тайны о производится вправе имущество участвующее постановления и с Российская Федерации – увазанного назначаемы, но явках.
#  Обязан ввозимых лиц, надзоров и оказавее 109 настоящего Кодексом.
#
#  Ст
# ----
# Text generated by picking most likely letters
# Using random seed: ием докуме
# ----
#  ием документов и по делу об административного штрафа на граждан в размере от двадцати до двадцати до двадцати до двадцати до двадцати до двадцати до двадцати до двадцати до двадцати до двадцати до двадцати до д
# ----
# Epoch 80 average loss = 0.949202120711
# Text generated proportionally to probabilities
# Using random seed: ниях, сове
# ----
#  ниях, совершение при учебных общести: Когда имел эти время (егвости о зачисственно отправлению пункта, котогым образований, а в отношении подлежит равнот в пись цели к действие средства на незаторе и возможных
# ----
# Text generated by picking most likely letters
# Using random seed: тья 1205.
# ----
#  тья 1205.
#  Право на срок до принятия правил и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязанности и обязаннос
# ----
# Epoch 81 average loss = 0.946483731806
# Text generated proportionally to probabilities
# Using random seed: ждено дело
# ----
#  ждено дело, хотя бентами по органа, подкладет его условия об отмене другой вклада товаров, если непредставлено наследство и наличие и проверки исходя изнавенднуграта. Если доверительного государством Российскую
# ----
# Text generated by picking most likely letters
# Using random seed: (поста) и
# ----
#  (поста) и при наличии при недоставки и при наличии при недоставки и при наличии при недоставки и при наличии при недоставки и при наличии при недоставки и при наличии при недоставки и при наличии при недоставки
# ----
# Epoch 82 average loss = 0.947309404841
# Text generated proportionally to probabilities
# Using random seed: ри наличии
# ----
#  ри наличии находи таможенные пунктом 9 настоящего Кодекса, одинактив земельным участие несет осуществляет пунктом 7д жилого и меноданиебвичения;
#  судебного пристав представителей) вправе:
# , дежураственный сро
# ----
# Text generated by picking most likely letters
# Using random seed: ной, госуд
# ----
#  ной, государственного права и обязан при принятия правила об отказе в соответствии совершения правила об отказе в соответствии совершения правила об отказе в соответствии совершения правила об отказе в соответс
# ----
# Epoch 83 average loss = 0.951872723655
# Text generated proportionally to probabilities
# Using random seed:  настоящег
# ----
#   настоящего Кодекса.
#  3. Заявление операции, составе на определение охрана выдана о их состоянии и методе бир Российской Федерации.
#
#  Статья 156.
#  Отчима не и вещью получатель лицу;
#  – ведения в положения)
# ----
# Text generated by picking most likely letters
# Using random seed: ного лица
# ----
#  ного лица
#
#  1. При привлекает производится об отменения при привлекает производится об отменения при привлекает производится об отменения при привлекает производится об отменения при привлекает производится о
# ----
# Epoch 84 average loss = 0.944429142801
# Text generated proportionally to probabilities
# Using random seed: налогов. В
# ----
#  налогов. В Реестоно на основное.
#
#  Статья 203.
#  Лицо о ведении выплошать исполнение установленно. Обеспечивающий произведении распоряжение;
#  3) за заменаружении вправе производственных плателем, если им ука
# ----
# Text generated by picking most likely letters
# Using random seed:  Федерации
# ----
#   Федерации и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и правилам и
# ----
# Epoch 85 average loss = 0.953100649199
# Text generated proportionally to probabilities
# Using random seed: ак объект
# ----
#  ак объект не совершать завещания на аресток указания обязательства, комиссионера, умерших установление Презнаками при право и 5 статьи 30-О, нв исключитель ввозный, определениза не определенному другого право ю
# ----
# Text generated by picking most likely letters
# Using random seed: но быть сд
# ----
#  но быть сделку и при предусмотренных статьей 200 настоящего Кодекса в соответствии с пользования при предусмотренных статьей 200 настоящего Кодекса в соответствии с пользования при предусмотренных статьей 200 н
# ----
# Epoch 86 average loss = 0.945116034311
# Text generated proportionally to probabilities
# Using random seed:  3. Предст
# ----
#   3. Представления правил часть Экономикному или учрежденого, не предусмотренных Статьей 110 настоящего Закона от 10.12.2003 №509-ФЗ)
#  Кредитором в договоре, адриничаться не разрешения и дрягу, стоодовстванами
# ----
# Text generated by picking most likely letters
# Using random seed:  попечител
# ----
#   попечительством Российской Федерации и принимать дело об административного штрафа на граждан в размере от двадцати до двадцати до двадцати до двадцати до двадцати до двадцати до двадцати до двадцати до двадцат
# ----
# Epoch 87 average loss = 0.942077008565
# Text generated proportionally to probabilities
# Using random seed: аховой сум
# ----
#  аховой сумме охрану юридических лиц лицо, илу памяет вреда, испольмо, иностранные государственные в противопистному протоколы граждане.
#  В запросы по истентии и приложенности ополности, установление от дежучны
# ----
# Text generated by picking most likely letters
# Using random seed: мпенсацию
# ----
#  мпенсацию и принятия обращение о принятия обращение о принятия обращение о принятия обращение о принятия обращение о принятия обращение о принятия обращение о принятия обращение о принятия обращение о принятия
# ----
# Epoch 88 average loss = 0.948921268488
# Text generated proportionally to probabilities
# Using random seed: ругих орга
# ----
#  ругих организаций вправе административном правонарушение пределах, исполнителя (записы обучений, дреступков времени, определения, право из наследованных возврата, – условия, судьи хранения, которого применения,
# ----
# Text generated by picking most likely letters
# Using random seed: м суде пер
# ----
#  м суде переданного положения и при наследование по договору на принятии права и при наследование по договору на принятии права и при наследование по договору на принятии права и при наследование по договору на
# ----
# Epoch 89 average loss = 0.94687711183
# Text generated proportionally to probabilities
# Using random seed: енную служ
# ----
#  енную службы у независимо от обязанностью. Организыхельная имущества вывозе ограничение о своему междунительно о признаны в такую  арест, и иняетсях за ничтолонне и другому в Российской Федерации;
#  4) имуществ
# ----
# Text generated by picking most likely letters
# Using random seed: азмере от
# ----
#  азмере от десяти до двадцати до тридцати до двадцати до тридцати до двадцати до тридцати до двадцати до тридцати до двадцати до тридцати до двадцати до тридцати до двадцати до тридцати до двадцати до тридцати д
# ----
# Epoch 90 average loss = 0.942713543883
# Text generated proportionally to probabilities
# Using random seed:  статьи не
# ----
#   статьи не подлежит и ценилишини, которая ввоза от имперуального лица, иных направить транспортировки, являются в этому иденка)
#
#  С или принятахсях к 1003 настоящего Кодекса;
#  8.
#
#  Статья 17.
#  2. Не насле
# ----
# Text generated by picking most likely letters
# Using random seed: анию истек
# ----
#  анию истекается в случае обязательной собственности на срок и обязательной собственности на срок и обязательной собственности на срок и обязательной собственности на срок и обязательной собственности на срок и
# ----
# Epoch 91 average loss = 0.941925120687
# Text generated proportionally to probabilities
# Using random seed:  о том, чт
# ----
#   о том, что продавать в пределах службы
#
#  1. Правовому пойжилованным завещания.
#  В договоре кредитной рения и охраннымно с определенно. Таможенной декларации определение и иной 385
#
#  1. В части 6 статьи 41
# ----
# Text generated by picking most likely letters
# Using random seed: ьной книжк
# ----
#  ьной книжкы и оборудования об отказе от предусмотренных настоящим Кодексом.
#  2. Продавать предпринимательской деятельность предусмотренных настоящим Кодексом.
#  2. Продавать предпринимательской деятельность пр
# ----
# Epoch 92 average loss = 0.936225811002
# Text generated proportionally to probabilities
# Using random seed: образовани
# ----
#  образования взыскания;
#  7) в федеральным зрезвычай отменное обязательств, не выражить являющегося Правления, сделоков о провертной) люддир в суды, один проводится для взыскать цасткупложайное колиме наследстве
# ----
# Text generated by picking most likely letters
# Using random seed: аключены т
# ----
#  аключены такого производственного достоинстводателя обязательства и признании и признании и признании и признании и признании и признании и признании и признании и признании и признании и признании и признании
# ----
# Epoch 93 average loss = 0.937304753606
# Text generated proportionally to probabilities
# Using random seed: аз от испо
# ----
#  аз от исполняющее возбуждением
#
#  1. Если неосъединение сторона, иных общего государственного законом.
#  При этом прав по ренты бы временное ненадлежащим повупали (упроменьшего исполнить решения не предусмотре
# ----
# Text generated by picking most likely letters
# Using random seed: еменного х
# ----
#  еменного хранения или предпринимательской деятельности или предпринимательской деятельности или предпринимательской деятельности или предпринимательской деятельности или предпринимательской деятельности или пре
# ----
# Epoch 94 average loss = 0.939784188336
# Text generated proportionally to probabilities
# Using random seed: ят новый с
# ----
#  ят новый средств в тамися с эксперции месту несудекств посли почтодению.
#
#  Статьи 265).
#  Срок порежащиесть либо прав и отказа
#
#  Полном общая удостоверена-привох российского) по словы
#
#  1. Заработконная з
# ----
# Text generated by picking most likely letters
# Using random seed: енных сост
# ----
#  енных составляется производственной порядка и принятие правовыми актами и принятие правовыми актами и принятие правовыми актами и принятие правовыми актами и принятие правовыми актами и принятие правовыми актам
# ----
# Epoch 95 average loss = 0.937724005188
# Text generated proportionally to probabilities
# Using random seed: тья 350),
# ----
#  тья 350), если сыднального состояния имущества от собственностью прежьве сторона
#
#  Заказ Российской Федерации лиц о торговения с суда (в единых решений обязательное).
#  2. Ограничивается це кабельном участник
# ----
# Text generated by picking most likely letters
# Using random seed:  уменьшенн
# ----
#   уменьшенных права собственностью или при осуществляется или соответствующего пользования при осуществляется или соответствующего пользования при осуществляется или соответствующего пользования при осуществляет
# ----
# Epoch 96 average loss = 0.945782790444
# Text generated proportionally to probabilities
# Using random seed: ями 292 и
# ----
#  ями 292 и 4005.
#  Выдечанию, за исключении договора или срок наименового акта применения, если заявителя.
#  3. Ненаданизательскую поступление о процента.
#  Отказом финансов пругосимательской концексации органы;
# ----
# Text generated by picking most likely letters
# Using random seed: сийской Фе
# ----
#  сийской Федерации и принять производственного срока при принятия настоящей статьи, принять производственного срока при принятия настоящей статьи, принять производственного срока при принятия настоящей статьи, п
# ----
# Epoch 97 average loss = 0.942088455426
# Text generated proportionally to probabilities
# Using random seed: обеспечени
# ----
#  обеспечении о нехррта.
#
#  Статья 718.
#  Ответственности наследства может сторона в сторон с протериимим потребовать несение этой собственного имения или других празим) счет издоловано совершивших в гоказ страх
# ----
# Text generated by picking most likely letters
# Using random seed: и по закон
# ----
#  и по законных срок и обязательства и принятии таможенных пошлин, налогов и принятии таможенных пошлин, налогов и принятии таможенных пошлин, налогов и принятии таможенных пошлин, налогов и принятии таможенных п
# ----
# Epoch 98 average loss = 0.944718478444
# Text generated proportionally to probabilities
# Using random seed: ражного су
# ----
#  ражного судах, предусмотрены в соответствуют кектах – решению объемя зонируется для предмет предоставлении для предъявить деятельности или должника остоятелю Российской Федерации;
#  – в соответственности произв
# ----
# Text generated by picking most likely letters
# Using random seed:
#  Доверите
# ----
#
#  Доверительного представителя и принятия производства по делу об административного штрафа на граждан и обязанности и принятия производства по делу об административного штрафа на граждан и обязанности и приняти
# ----
# Epoch 99 average loss = 0.944039817741

# %% [markdown]
# # A chance to speed up training and get bonus score
# * Try predicting next token probas at ALL ticks (like in the seminar part)
# * much more objectives, much better gradients
# * You may want to zero-out loss for first several iterations

# %% [markdown]
# # The New World Order

# %%
seed = u"Каждый человек должен"
sampling_fun = proportional_sample_fun
result_length = 300

generate_sample(sampling_fun,seed,result_length)
# Out:
# ----
#  век должен совершении которых граждан словных органы без согласия действие общества обязательствам, праве фиксации его заявлению такое гарант и транспертным средств его кредитном ремелимой целей осуществление месяца по договору, должностного получение денежного потребовать быть возмещения допускается исполнен
# ----

# %%
seed = u"В случае неповиновения"
sampling_fun = proportional_sample_fun
result_length = 300

generate_sample(sampling_fun,seed,result_length)
# Out:
# ----
#  овиновениях действия несоцше сведения ведения эворе транспорта арбитражного суды, последования
#
#  1. Если им возмещение таможенности, сооружение завещания или распространных, внутренних дел.
#  2. Соракенных и юредуяи двух минимальных размеров оплаты труда с конструкций предупреждении объеме ступленному покуп
# ----
