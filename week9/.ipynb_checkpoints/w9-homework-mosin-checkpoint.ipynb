# %% [markdown]
# ### ***Vasilii Mosin***

# %%
#coding: utf-8

import warnings
warnings.simplefilter("ignore")

import os
import sys 
import wave
import time
import librosa
import numpy as np
from utils import *
import matplotlib.pyplot as plt
from IPython.display import Audio
from StringIO import StringIO

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !wget https://www.dropbox.com/s/jtdc7y0bi00ii4p/genres.tar.gz?dl=0 -O genres.tar.gz 
# !tar -xzf genres.tar.gz

# %%
import IPython
from IPython import display

def Audio(url):
    return display.HTML("<center><audio controls><source src='{}'></audio>".format(url))

# %%
sound_file = './genres/blues/blues.00000.au'

y, sr = librosa.load(sound_file)
librosa.output.write_wav('./genres/tmp.wav', y, sr, norm=True)
Audio(url='./genres/tmp.wav')
# Out:
# <center><audio controls><source src='./genres/tmp.wav'></audio>

# %% [markdown]
# # Sound as 1D-Signal

# %%
plt.figure(figsize=(20,4))
pylab.plot(np.arange(len(y)) * 1.0 /sr, y, 'k')
pylab.xlim([0, 10])
pylab.show()

# %% [markdown]
# # Sound as 2D-Signal

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)
log_S = librosa.logamplitude(S, ref_power=np.max)

# %%
plt.figure(figsize=(20,4))
librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel', cmap='hot')
plt.title('mel power spectrogram')
plt.colorbar(format='%+02.0f dB')
plt.tight_layout()

# %%
def get_spectgorgamm(fname):
    y, sr = librosa.load(fname)
    S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)
    log_S = librosa.logamplitude(S, ref_power=np.max)
    return log_S[:, :1200]

def plot_spectrogramm(log_S):
    plt.figure(figsize=(20,4))
    librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel', cmap='hot')
    plt.title('mel power spectrogram')
    plt.colorbar(format='%+02.0f dB')
    plt.tight_layout()

# %% [markdown]
# # Prepare a data

# %%
geners = ['blues', 'country', 'hiphop', 'metal', 'reggae', 'classical', 'disco', 'jazz', 'pop', 'rock']

id2gener = dict()
X_names, y = [], []
for gener_id, gener in enumerate(geners):
    id2gener[gener_id] = gener
    for track in os.listdir('./genres/' + gener):
        if '.mp3' in track or '.au' in track and '_' not in track:
            trackfile = os.path.join('./genres/', gener, track)
            X_names.append(trackfile)
            y.append(gener_id)

# %%
from multiprocessing import Pool

ncpu = 4
X = Pool(ncpu).map(get_spectgorgamm, X_names)

# %% [markdown]
# # Nearest Neighbors genre classification

# %%
perm = np.random.permutation(len(y))
X, X_names, y = np.array(X)[perm].astype('float32'), np.array(X_names)[perm], np.array(y)[perm]
Xreshape = X.reshape(X.shape[0], X.shape[1], X.shape[2])

X_train, X_valid = Xreshape[:800], Xreshape[800:]
y_train, y_valid = y[:800], y[800:]

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier(n_jobs=ncpu)

clf = clf.fit(X_train.reshape((X_train.shape[0], -1)), y_train)
y_val_pred = clf.predict(X_valid.reshape((X_valid.shape[0], -1)))

print accuracy_score(y_valid, y_val_pred)
# Out:
# 0.41

# %% [markdown]
# # Convolution Nural Nets

# %% [markdown]
# ![](http://benanne.github.io/images/spotify_convnet.png)
#
# http://benanne.github.io/2014/08/05/spotify-cnns.html

# %%
import theano
import lasagne
import theano.tensor as T

# %%
perm = np.random.permutation(len(y))
X, y = np.array(X)[perm].astype('float32'), np.array(y)[perm]
Xreshape = X.reshape(X.shape[0], X.shape[1], X.shape[2])

X_train, X_valid = Xreshape[:800], Xreshape[800:]
y_train, y_valid = y[:800], y[800:]

input_X, target_y = T.tensor3("X", dtype='float64'), T.vector("y", dtype='int32')
nn = lasagne.layers.InputLayer(shape=(None, X.shape[1], X.shape[2]), input_var=input_X) 

nn = lasagne.layers.Conv1DLayer(nn, 32, 4)
nn = lasagne.layers.MaxPool1DLayer(nn, 2)

nn = lasagne.layers.Conv1DLayer(nn, 32, 3)
nn = lasagne.layers.MaxPool1DLayer(nn, 2)

nn = lasagne.layers.Conv1DLayer(nn, 32, 3)
nn = lasagne.layers.MaxPool1DLayer(nn, 2)

nn = lasagne.layers.Conv1DLayer(nn, 64, 3)
nn = lasagne.layers.GlobalPoolLayer(nn)

nn = lasagne.layers.DenseLayer(nn, num_units=300)
nn = lasagne.layers.DropoutLayer(nn, 0.3)
nn = lasagne.layers.DenseLayer(nn, num_units=300)
nn = lasagne.layers.DenseLayer(nn, 10, nonlinearity=lasagne.nonlinearities.softmax)

# %%
y_predicted = lasagne.layers.get_output(nn)
all_weights = lasagne.layers.get_all_params(nn)

loss = lasagne.objectives.categorical_crossentropy(y_predicted, target_y).mean()
accuracy = lasagne.objectives.categorical_accuracy(y_predicted, target_y).mean()
updates_sgd = lasagne.updates.adam(loss, all_weights)

# %%
train_fun = theano.function([input_X, target_y], [loss, accuracy], allow_input_downcast=True, updates=updates_sgd)
test_fun  = theano.function([input_X, target_y], [loss, accuracy], allow_input_downcast=True)

# %%
# %%time 

conv_nn = train_net(nn, train_fun, test_fun, X_train, y_train, X_valid, y_valid, num_epochs=100, batch_size=50)
# Out:
# Epoch   1 of 100 train_loss = 1.71 val_loss = 1.74 train_acc = 35.38 val_acc = 38.00
# Epoch   2 of 100 train_loss = 1.65 val_loss = 1.70 train_acc = 37.88 val_acc = 42.50
# Epoch   3 of 100 train_loss = 1.61 val_loss = 1.69 train_acc = 39.00 val_acc = 38.50
# Epoch   4 of 100 train_loss = 1.50 val_loss = 1.55 train_acc = 43.38 val_acc = 44.50
# Epoch   5 of 100 train_loss = 1.51 val_loss = 1.56 train_acc = 39.75 val_acc = 42.50
# Epoch   6 of 100 train_loss = 1.52 val_loss = 1.52 train_acc = 40.75 val_acc = 40.00
# Epoch   7 of 100 train_loss = 1.49 val_loss = 1.50 train_acc = 43.12 val_acc = 45.50
# Epoch   8 of 100 train_loss = 1.42 val_loss = 1.58 train_acc = 45.75 val_acc = 39.00
# Epoch   9 of 100 train_loss = 1.43 val_loss = 1.55 train_acc = 48.63 val_acc = 39.50
# Epoch  10 of 100 train_loss = 1.39 val_loss = 1.42 train_acc = 48.12 val_acc = 45.00
# Epoch  11 of 100 train_loss = 1.40 val_loss = 1.51 train_acc = 46.25 val_acc = 44.50
# Epoch  12 of 100 train_loss = 1.47 val_loss = 1.40 train_acc = 44.38 val_acc = 48.00
# Epoch  13 of 100 train_loss = 1.34 val_loss = 1.53 train_acc = 50.13 val_acc = 44.50
# Epoch  14 of 100 train_loss = 1.46 val_loss = 1.48 train_acc = 42.75 val_acc = 47.00
# Epoch  15 of 100 train_loss = 1.38 val_loss = 1.45 train_acc = 47.62 val_acc = 47.50
# Epoch  16 of 100 train_loss = 1.31 val_loss = 1.60 train_acc = 49.12 val_acc = 44.50
# Epoch  17 of 100 train_loss = 1.34 val_loss = 1.43 train_acc = 49.13 val_acc = 46.50
# Epoch  18 of 100 train_loss = 1.27 val_loss = 1.40 train_acc = 53.75 val_acc = 50.50
# Epoch  19 of 100 train_loss = 1.25 val_loss = 1.32 train_acc = 55.00 val_acc = 52.50
# Epoch  20 of 100 train_loss = 1.30 val_loss = 1.45 train_acc = 50.88 val_acc = 54.00
# Epoch  21 of 100 train_loss = 1.25 val_loss = 1.38 train_acc = 51.88 val_acc = 53.50
# Epoch  22 of 100 train_loss = 1.24 val_loss = 1.32 train_acc = 54.12 val_acc = 50.50
# Epoch  23 of 100 train_loss = 1.21 val_loss = 1.39 train_acc = 55.88 val_acc = 50.00
# Epoch  24 of 100 train_loss = 1.20 val_loss = 1.25 train_acc = 55.88 val_acc = 56.50
# Epoch  25 of 100 train_loss = 1.17 val_loss = 1.27 train_acc = 57.00 val_acc = 54.50
# Epoch  26 of 100 train_loss = 1.17 val_loss = 1.25 train_acc = 57.12 val_acc = 55.00
# Epoch  27 of 100 train_loss = 1.15 val_loss = 1.27 train_acc = 57.75 val_acc = 57.50
# Epoch  28 of 100 train_loss = 1.11 val_loss = 1.24 train_acc = 58.75 val_acc = 55.50
# Epoch  29 of 100 train_loss = 1.11 val_loss = 1.33 train_acc = 57.25 val_acc = 48.50
# Epoch  30 of 100 train_loss = 1.17 val_loss = 1.42 train_acc = 54.75 val_acc = 49.00
# Epoch  31 of 100 train_loss = 1.16 val_loss = 1.17 train_acc = 56.00 val_acc = 61.00
# Epoch  32 of 100 train_loss = 1.13 val_loss = 1.50 train_acc = 56.50 val_acc = 44.50
# Epoch  33 of 100 train_loss = 1.18 val_loss = 1.22 train_acc = 53.50 val_acc = 56.00
# Epoch  34 of 100 train_loss = 1.10 val_loss = 1.26 train_acc = 59.50 val_acc = 53.50
# Epoch  35 of 100 train_loss = 1.08 val_loss = 1.22 train_acc = 59.00 val_acc = 57.50
# Epoch  36 of 100 train_loss = 1.06 val_loss = 1.30 train_acc = 61.00 val_acc = 54.00
# Epoch  37 of 100 train_loss = 1.08 val_loss = 1.33 train_acc = 59.63 val_acc = 52.50
# Epoch  38 of 100 train_loss = 1.14 val_loss = 1.28 train_acc = 57.62 val_acc = 56.50
# Epoch  39 of 100 train_loss = 1.01 val_loss = 1.18 train_acc = 63.00 val_acc = 57.50
# Epoch  40 of 100 train_loss = 0.99 val_loss = 1.14 train_acc = 63.38 val_acc = 59.00
# Epoch  41 of 100 train_loss = 0.98 val_loss = 1.10 train_acc = 63.50 val_acc = 63.50
# Epoch  42 of 100 train_loss = 0.98 val_loss = 1.25 train_acc = 64.50 val_acc = 52.00
# Epoch  43 of 100 train_loss = 1.06 val_loss = 1.23 train_acc = 58.50 val_acc = 55.00
# Epoch  44 of 100 train_loss = 1.00 val_loss = 1.23 train_acc = 63.00 val_acc = 57.00
# Epoch  45 of 100 train_loss = 0.99 val_loss = 1.36 train_acc = 64.00 val_acc = 54.00
# Epoch  46 of 100 train_loss = 1.14 val_loss = 1.37 train_acc = 57.75 val_acc = 52.00
# Epoch  47 of 100 train_loss = 1.04 val_loss = 1.24 train_acc = 62.25 val_acc = 61.00
# Epoch  48 of 100 train_loss = 0.93 val_loss = 1.15 train_acc = 65.62 val_acc = 57.50
# Epoch  49 of 100 train_loss = 0.89 val_loss = 1.16 train_acc = 66.00 val_acc = 60.00
# Epoch  50 of 100 train_loss = 0.88 val_loss = 1.13 train_acc = 66.50 val_acc = 62.00
# Epoch  51 of 100 train_loss = 0.89 val_loss = 1.15 train_acc = 65.75 val_acc = 64.00
# Epoch  52 of 100 train_loss = 0.88 val_loss = 1.16 train_acc = 68.37 val_acc = 62.50
# Epoch  53 of 100 train_loss = 0.86 val_loss = 1.29 train_acc = 67.75 val_acc = 61.00
# Epoch  54 of 100 train_loss = 0.92 val_loss = 1.26 train_acc = 64.88 val_acc = 58.00
# Epoch  55 of 100 train_loss = 0.86 val_loss = 1.19 train_acc = 67.50 val_acc = 62.00
# Epoch  56 of 100 train_loss = 0.83 val_loss = 1.11 train_acc = 68.88 val_acc = 64.00
# Epoch  57 of 100 train_loss = 0.87 val_loss = 1.16 train_acc = 67.25 val_acc = 64.50
# Epoch  58 of 100 train_loss = 0.84 val_loss = 1.27 train_acc = 68.00 val_acc = 57.50
# Epoch  59 of 100 train_loss = 0.83 val_loss = 1.21 train_acc = 69.00 val_acc = 63.00
# Epoch  60 of 100 train_loss = 0.82 val_loss = 1.11 train_acc = 68.12 val_acc = 67.00
# Epoch  61 of 100 train_loss = 0.85 val_loss = 1.08 train_acc = 68.50 val_acc = 61.50
# Epoch  62 of 100 train_loss = 0.80 val_loss = 1.07 train_acc = 70.75 val_acc = 66.50
# Epoch  63 of 100 train_loss = 0.77 val_loss = 1.19 train_acc = 71.62 val_acc = 63.50
# Epoch  64 of 100 train_loss = 0.73 val_loss = 1.13 train_acc = 71.75 val_acc = 62.50
# Epoch  65 of 100 train_loss = 0.81 val_loss = 1.29 train_acc = 69.87 val_acc = 57.00
# Epoch  66 of 100 train_loss = 0.80 val_loss = 1.11 train_acc = 70.25 val_acc = 66.00
# Epoch  67 of 100 train_loss = 0.73 val_loss = 1.05 train_acc = 72.87 val_acc = 66.50
# Epoch  68 of 100 train_loss = 0.69 val_loss = 1.09 train_acc = 74.88 val_acc = 69.50
# Epoch  69 of 100 train_loss = 0.73 val_loss = 1.02 train_acc = 72.12 val_acc = 68.00
# Epoch  70 of 100 train_loss = 0.78 val_loss = 1.22 train_acc = 70.50 val_acc = 63.50
# Epoch  71 of 100 train_loss = 0.77 val_loss = 1.37 train_acc = 71.00 val_acc = 58.50
# Epoch  72 of 100 train_loss = 0.81 val_loss = 1.28 train_acc = 68.88 val_acc = 54.50
# Epoch  73 of 100 train_loss = 0.73 val_loss = 1.07 train_acc = 73.62 val_acc = 63.00
# Epoch  74 of 100 train_loss = 0.75 val_loss = 1.06 train_acc = 71.62 val_acc = 66.50
# Epoch  75 of 100 train_loss = 0.69 val_loss = 1.16 train_acc = 74.38 val_acc = 62.00
# Epoch  76 of 100 train_loss = 0.73 val_loss = 1.08 train_acc = 72.75 val_acc = 63.50
# Epoch  77 of 100 train_loss = 0.67 val_loss = 1.18 train_acc = 76.50 val_acc = 62.00
# Epoch  78 of 100 train_loss = 0.68 val_loss = 1.22 train_acc = 76.38 val_acc = 62.50
# Epoch  79 of 100 train_loss = 0.76 val_loss = 1.17 train_acc = 71.37 val_acc = 64.00
# Epoch  80 of 100 train_loss = 0.70 val_loss = 1.22 train_acc = 74.12 val_acc = 64.00
# Epoch  81 of 100 train_loss = 0.67 val_loss = 1.12 train_acc = 76.50 val_acc = 65.00
# Epoch  82 of 100 train_loss = 0.70 val_loss = 1.10 train_acc = 73.75 val_acc = 64.50
# Epoch  83 of 100 train_loss = 0.68 val_loss = 1.11 train_acc = 76.25 val_acc = 65.50
# Epoch  84 of 100 train_loss = 0.58 val_loss = 1.28 train_acc = 79.00 val_acc = 61.50
# Epoch  85 of 100 train_loss = 0.59 val_loss = 1.35 train_acc = 77.62 val_acc = 60.50
# Epoch  86 of 100 train_loss = 0.61 val_loss = 1.01 train_acc = 78.50 val_acc = 70.00
# Epoch  87 of 100 train_loss = 0.59 val_loss = 1.20 train_acc = 77.75 val_acc = 62.50
# Epoch  88 of 100 train_loss = 0.65 val_loss = 1.22 train_acc = 74.25 val_acc = 62.50
# Epoch  89 of 100 train_loss = 0.70 val_loss = 1.07 train_acc = 73.00 val_acc = 69.00
# Epoch  90 of 100 train_loss = 0.58 val_loss = 1.14 train_acc = 77.88 val_acc = 67.50
# Epoch  91 of 100 train_loss = 0.59 val_loss = 1.14 train_acc = 78.37 val_acc = 65.00
# Epoch  92 of 100 train_loss = 0.55 val_loss = 1.14 train_acc = 78.75 val_acc = 67.50
# Epoch  93 of 100 train_loss = 0.58 val_loss = 1.03 train_acc = 78.13 val_acc = 69.50
# Epoch  94 of 100 train_loss = 0.50 val_loss = 1.07 train_acc = 81.50 val_acc = 68.00
# Epoch  95 of 100 train_loss = 0.50 val_loss = 1.15 train_acc = 81.12 val_acc = 68.50
# Epoch  96 of 100 train_loss = 0.48 val_loss = 1.09 train_acc = 82.12 val_acc = 70.00
# Epoch  97 of 100 train_loss = 0.44 val_loss = 1.04 train_acc = 83.88 val_acc = 68.50
# Epoch  98 of 100 train_loss = 0.48 val_loss = 1.24 train_acc = 82.13 val_acc = 67.50
# Epoch  99 of 100 train_loss = 0.45 val_loss = 1.21 train_acc = 85.00 val_acc = 69.00
# Epoch 100 of 100 train_loss = 0.48 val_loss = 1.31 train_acc = 82.75 val_acc = 67.00
# CPU times: user 52min 58s, sys: 24min 5s, total: 1h 17min 4s
# Wall time: 45min 13s

# %%
plt.figure(figsize=(5, 5), dpi=500)
W = lasagne.layers.get_all_params(nn)[0].get_value()
W[::2, :, :] = 0.2
W = np.hstack(W)
pylab.imshow(W, cmap='hot', interpolation="nearest")
pylab.axis('off')
pylab.show()

# %% [markdown]
# # Find Simular Tracks

# %% [markdown]
# <img src="./img/cnn_gr.png" width="500">

# %%
from sklearn.neighbors import NearestNeighbors

# %%
represent = lasagne.layers.get_output(nn.input_layer.input_layer)
represent_fun = theano.function([input_X], [represent], allow_input_downcast=True)

# %%
f = lambda x: np.array(represent_fun([x])[0])
track_vectors = map(f, X_train) + map(f, X_valid)
track_vectors = np.concatenate(track_vectors, axis=0)

# %%
nn_pred = NearestNeighbors(metric='cosine', algorithm='brute')

# %%
nn_pred = nn_pred.fit(track_vectors)

# %%
X_names[0]
# Out:
# './genres/hiphop/hiphop.00072.au'

# %%
ans = list(X_names[nn_pred.kneighbors(track_vectors[0])[1][0]])
ans
# Out:
# ['./genres/hiphop/hiphop.00072.au',
#  './genres/blues/blues.00045.au',
#  './genres/rock/rock.00083.au',
#  './genres/hiphop/hiphop.00078.au',
#  './genres/reggae/reggae.00025.au']

# %%
sound_file = ans[0]
y, sr = librosa.load(sound_file)
librosa.output.write_wav('./genres/tmp.wav', y, sr, norm=True)
Audio(url='./genres/tmp.wav')
# Out:
# <center><audio controls><source src='./genres/tmp.wav'></audio>

# %%
sound_file = ans[1]
y, sr = librosa.load(sound_file)
librosa.output.write_wav('./genres/tmp.wav', y, sr, norm=True)
Audio(url='./genres/tmp.wav')
# Out:
# <center><audio controls><source src='./genres/tmp.wav'></audio>

# %% [markdown]
# # Maps of tracks by svd and tsne

# %% [markdown]
# Help: https://lts2.epfl.ch/blog/perekres/category/visualizing-hidden-structures-in-datasets-using-deep-learning/

# %%
from sklearn.manifold import TSNE

# %%
represent = lasagne.layers.get_output(nn.input_layer)
represent_fun = theano.function([input_X], [represent], allow_input_downcast=True)

# %%
f = lambda x: np.array(represent_fun([x])[0])
track_vectors = map(f, X_train) + map(f, X_valid)
track_vectors = np.concatenate(track_vectors, axis=0)
track_labels = np.array(list(y_train) + list(y_valid))

# %%
X_tsne = TSNE(n_components=2).fit_transform(track_vectors)

# %%
plt.figure(figsize=(10,10), dpi=500)
colors = cm.hot(np.linspace(0, 1, len(id2gener)))

for idx, gener in id2gener.items():
    idx_ = np.where(track_labels == idx)
    pylab.scatter(X_tsne[:, 0][idx_], X_tsne[:, 1][idx_], c=colors[idx], cmap=cm.hot, label=gener,s=50)

pylab.legend(loc=0, ncol=5)

# %% [markdown]
# CNN showed much better results (almost 70% accuracy on validation dataset) comparing to KNearestNeighbors classification with about 40% accuracy. Also, we've used our trained network for finding similar tracks. Plot via TSNE showes how our network grouped tracks by geners well enough.
